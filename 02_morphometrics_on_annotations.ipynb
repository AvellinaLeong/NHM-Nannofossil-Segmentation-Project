# %% [markdown]
# <a href="https://colab.research.google.com/github/AvellinaLeong/NHM-Nannofossil-Segmentation-Project/blob/main/02_morphometrics_on_annotations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Morphometrics on train, test and val annotations
#
# Morphometric parameters:
#
#
# *   Major axis
# *   Minor axis
# *   Circularity
# *   Ellipticity
# *   Area

# %%
from google.colab import drive
drive.mount('/content/drive/')

# Set script location to own development space
MY_DEVELOPMENT_SPACE = '/content/drive/MyDrive/development/avellina/'
import os
os.chdir(MY_DEVELOPMENT_SPACE)
# !pwd
# !ls
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/development/avellina
# detectron2  Detectron2_notebooks  Mask-RCNN  Morphometrics_notebooks  output

# %%
import os
import json
import csv
import cv2
import numpy as np
from skimage.measure import regionprops, label
from skimage.draw import polygon
from skimage.io import imread

# %%
# File paths
datasets = {
    "train": {
        "annotations_path": "/content/drive/MyDrive/data/species_16/data/train/e_turriseiffelii_label_train_coco.json",
        "images_directory": "/content/drive/MyDrive/data/species_16/data/train"
    },
    "val": {
        "annotations_path": "/content/drive/MyDrive/data/species_16/data/val/e_turriseiffelii_label_val_coco.json",
        "images_directory": "/content/drive/MyDrive/data/species_16/data/val"
    },
    "test": {
        "annotations_path": "/content/drive/MyDrive/data/species_16/data/test/e_turriseiffelii_label_test_coco.json",
        "images_directory": "/content/drive/MyDrive/data/species_16/data/test"
    }
}

output_csv_path = "/content/drive/MyDrive/data/species_16/morphometric_output/morphometrics_all.csv"

# %%
# Function to create a mask from COCO polygon annotations
def create_mask_from_annotation(image_shape, annotations):
    mask = np.zeros(image_shape, dtype=np.uint8)
    for annotation in annotations:
        polygons = [np.array(segment).reshape(-1, 2) for segment in annotation['segmentation']]
        for polygon_points in polygons:
            rr, cc = polygon(polygon_points[:, 1], polygon_points[:, 0], mask.shape)
            mask[rr, cc] = 1
    return mask

# %%
# Open CSV file for writing
with open(output_csv_path, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["file_name", "class_name", "object_number", "major_axis", "minor_axis", "circularity", "ellipticity", "area"])

    for dataset_name, dataset_info in datasets.items():
        annotations_path = dataset_info["annotations_path"]
        images_directory = dataset_info["images_directory"]

        # Load COCO annotations
        with open(annotations_path, 'r') as file:
            coco_annotations = json.load(file)

        # Create a dictionary to map image IDs to file names
        image_id_to_filename = {image['id']: image['file_name'] for image in coco_annotations['images']}

        # Iterate over images in the COCO annotations
        for annotation in coco_annotations['annotations']:
            image_id = annotation['image_id']
            image_filename = image_id_to_filename[image_id]
            image_path = os.path.join(images_directory, image_filename)

            # Read image
            image = imread(image_path)

            # Create mask
            mask = create_mask_from_annotation(image.shape[:2], [annotation])

            # Label connected components
            labeled_mask = label(mask)

            # Check if the mask is empty
            if np.count_nonzero(labeled_mask) == 0:
                print(f"Warning: Image {image_filename} has an empty mask. Skipping.")
                continue

            props = regionprops(labeled_mask)

            scale = 0.0735

            for i, prop in enumerate(props):
                object_number = i + 1

                # Print out region properties for debugging
                print(f"Image: {image_filename}, Object {object_number}:")
                print(f"  - Major Axis Length: {prop.major_axis_length}")

                # Handle edge case where minor_axis_length might be very small or zero -- debug solution
                try:
                    minor_axis_length = prop.minor_axis_length
                    if np.isnan(minor_axis_length) or minor_axis_length <= 0:
                        print(f"Warning: Object {object_number} in image {image_filename} has invalid minor_axis_length ({minor_axis_length}). Skipping.")
                        continue
                except Exception as e:
                    print(f"Warning: Object {object_number} in image {image_filename} has error in minor_axis_length calculation: {e}. Skipping.")
                    continue

                print(f"  - Minor Axis Length: {minor_axis_length}")

                max_diameter = prop.major_axis_length * scale
                min_diameter = prop.minor_axis_length * scale

                # Circularity and Ellipticity
                circularity = np.sqrt((min_diameter * max_diameter) / (max_diameter ** 2))
                ellipticity = max_diameter / min_diameter

                # Area
                area = prop.area * (scale ** 2)

                class_name = 'e. turriseiffelii'

                # Save to CSV
                csvwriter.writerow([image_filename, class_name, object_number, max_diameter, min_diameter, circularity, ellipticity, area])

print("Morphometrics successfully saved to CSV file.")
# Out:
# Image: PM_NF_4999_03_26.jpeg, Object 1:
#   - Major Axis Length: 68.1532975045294
#   - Minor Axis Length: 48.34539830814738
# Image: PM_NF_4999_14_44.jpeg, Object 1:
#   - Major Axis Length: 61.98824386181804
#   - Minor Axis Length: 43.980062766714845
# Image: PM_NF_4999_20_11.jpeg, Object 1:
#   - Major Axis Length: 102.85176504842383
#   - Minor Axis Length: 69.0653520559596
# Image: PM_NF_5053_02_8.jpeg, Object 1:
#   - Major Axis Length: 78.81190239610314
#   - Minor Axis Length: 56.00625157063443
# Image: PM_NF_5054_02_22.jpeg, Object 1:
#   - Major Axis Length: 93.39014140278348
#   - Minor Axis Length: 61.687907183922576
# Image: PM_NF_5065_11_40.jpeg, Object 1:
#   - Major Axis Length: 79.47428481570222
#   - Minor Axis Length: 56.091584761494474
# Image: PM_NF_5065_12_45.jpeg, Object 1:
#   - Major Axis Length: 67.99658658608931
#   - Minor Axis Length: 49.64206459929532
# Image: PM_NF_5065_25_37.jpeg, Object 1:
#   - Major Axis Length: 90.23679105653846
#   - Minor Axis Length: 65.49313908050858
# Image: PM_NF_5225_10_7.jpeg, Object 1:
#   - Major Axis Length: 125.11372928856505
#   - Minor Axis Length: 101.53655705740518
# Image: PM_NF_5226_02_29.jpeg, Object 1:
#   - Major Axis Length: 102.11262128214618
#   - Minor Axis Length: 78.1113175626473
# Image: PM_NF_5281_11_47.jpeg, Object 1:
#   - Major Axis Length: 98.00542666049495
#   - Minor Axis Length: 77.01610744954567
# Image: PM_NF_5285_01_35.jpeg, Object 1:
#   - Major Axis Length: 61.684166707848405
#   - Minor Axis Length: 42.60740704212363
# Image: PM_NF_5285_03_37.jpeg, Object 1:
#   - Major Axis Length: 89.66833606196235
#   - Minor Axis Length: 59.002168288407546
# Image: PM_NF_5285_06_34.jpeg, Object 1:
#   - Major Axis Length: 65.29327725188587
#   - Minor Axis Length: 45.007676080290246
# Image: PM_NF_5285_08_28.jpeg, Object 1:
#   - Major Axis Length: 53.64047912380304
#   - Minor Axis Length: 41.24200479171216
# Image: PM_NF_5285_10_47.jpeg, Object 1:
#   - Major Axis Length: 88.14807042254567
#   - Minor Axis Length: 65.10091598657056
# Image: PM_NF_5285_12_20.jpeg, Object 1:
#   - Major Axis Length: 64.81750910178566
#   - Minor Axis Length: 42.16935226361727
# Image: PM_NF_5285_13_47.jpeg, Object 1:
#   - Major Axis Length: 69.57330638664331
#   - Minor Axis Length: 46.57567582920658
# Image: PM_NF_5290_05_13.jpeg, Object 1:
#   - Major Axis Length: 65.69035602069923
#   - Minor Axis Length: 43.283548630860956
# Image: PM_NF_5290_09_48.jpeg, Object 1:
#   - Major Axis Length: 76.76584941170753
#   - Minor Axis Length: 51.029443239977404
# Image: PM_NF_5290_13_11.jpeg, Object 1:
#   - Major Axis Length: 100.95089462657751
#   - Minor Axis Length: 74.10457442318548
# Image: PM_NF_5291_01_5.jpeg, Object 1:
#   - Major Axis Length: 72.80379685788337
#   - Minor Axis Length: 44.596035300399244
# Image: PM_NF_5291_02_42.jpeg, Object 1:
#   - Major Axis Length: 80.68627056079416
#   - Minor Axis Length: 53.839543925092094
# Image: PM_NF_5291_04_15.jpeg, Object 1:
#   - Major Axis Length: 69.09932124946573
#   - Minor Axis Length: 48.00198142227287
# Image: PM_NF_5291_10_2.jpeg, Object 1:
#   - Major Axis Length: 72.62133806522863
#   - Minor Axis Length: 50.892810792778135
# Image: PM_NF_5291_10_42.jpeg, Object 1:
#   - Major Axis Length: 83.75906185454996
#   - Minor Axis Length: 50.894099710453254
# Image: PM_NF_5291_12_2.jpeg, Object 1:
#   - Major Axis Length: 71.04193391405705
#   - Minor Axis Length: 52.835825297927215
# Image: PM_NF_5291_12_13.jpeg, Object 1:
#   - Major Axis Length: 85.80063140213744
#   - Minor Axis Length: 59.130100554740366
# Image: PM_NF_5291_13_12.jpeg, Object 1:
#   - Major Axis Length: 73.52775131400332
#   - Minor Axis Length: 57.893145880641754
# Image: PM_NF_5291_13_40.jpeg, Object 1:
#   - Major Axis Length: 108.3378462017392
#   - Minor Axis Length: 81.39052374240694
# Image: PM_NF_5291_15_33.jpeg, Object 1:
#   - Major Axis Length: 77.10475547485062
#   - Minor Axis Length: 52.97895651259555
# Image: PM_NF_5291_15_38.jpeg, Object 1:
#   - Major Axis Length: 74.42917130229357
#   - Minor Axis Length: 53.114813326491515
# Image: PM_NF_5291_19_10.jpeg, Object 1:
#   - Major Axis Length: 81.5146117383446
#   - Minor Axis Length: 64.02716960429328
# Image: PM_NF_5291_23_29.jpeg, Object 1:
#   - Major Axis Length: 78.50496223596988
#   - Minor Axis Length: 57.85346117096649
# Image: PM_NF_5291_27_35.jpeg, Object 1:
#   - Major Axis Length: 65.84314042146023
#   - Minor Axis Length: 50.323862974353865
# Image: PM_NF_5294_06_20.jpeg, Object 1:
#   - Major Axis Length: 74.85456159286605
#   - Minor Axis Length: 59.93791621126903
# Image: PM_NF_5294_07_46.jpeg, Object 1:
#   - Major Axis Length: 88.75440701049534
#   - Minor Axis Length: 65.00775662987108
# Image: PM_NF_5295_06_37.jpeg, Object 1:
#   - Major Axis Length: 82.34926021894204
#   - Minor Axis Length: 59.58043208278959
# Image: PM_NF_5300_05_1.jpeg, Object 1:
#   - Major Axis Length: 114.16060324602653
#   - Minor Axis Length: 93.73828974830576
# Image: PM_NF_5300_11_11.jpeg, Object 1:
#   - Major Axis Length: 99.7265213559881
#   - Minor Axis Length: 69.06353751119079
# Image: PM_NF_5301_01_3.jpeg, Object 1:
#   - Major Axis Length: 112.17464317141003
#   - Minor Axis Length: 90.04083279202668
# Image: PM_NF_5301_01_46.jpeg, Object 1:
#   - Major Axis Length: 110.85502141631756
#   - Minor Axis Length: 85.77868659065675
# Image: PM_NF_5301_02_8.jpeg, Object 1:
#   - Major Axis Length: 66.65178979770742
#   - Minor Axis Length: 46.59321382574402
# Image: PM_NF_5301_05_24.jpeg, Object 1:
#   - Major Axis Length: 79.37037093828019
#   - Minor Axis Length: 53.39116036834245
# Image: PM_NF_5301_06_37.jpeg, Object 1:
#   - Major Axis Length: 108.99041300541339
#   - Minor Axis Length: 83.72930318198749
# Image: PM_NF_5306_09_38.jpeg, Object 1:
#   - Major Axis Length: 124.27373239457305
#   - Minor Axis Length: 95.90862285750717
# Image: PM_NF_5306_25_35.jpeg, Object 1:
#   - Major Axis Length: 75.94301457161211
#   - Minor Axis Length: 52.41828799214676
# Image: PM_NF_5306_30_40.jpeg, Object 1:
#   - Major Axis Length: 98.76546580287113
#   - Minor Axis Length: 67.38211675126485
# Image: PM_NF_5306_37_20.jpeg, Object 1:
#   - Major Axis Length: 56.413570742374084
#   - Minor Axis Length: 38.356598424739516
# Image: PM_NF_5306_44_45.jpeg, Object 1:
#   - Major Axis Length: 101.52546195709161
#   - Minor Axis Length: 69.08344260972358
# Image: PM_NF_5306_110_26.jpeg, Object 1:
#   - Major Axis Length: 68.65954148349972
#   - Minor Axis Length: 43.68821968025396
# Image: PM_NF_5306_114_7.jpeg, Object 1:
#   - Major Axis Length: 69.45877823669316
#   - Minor Axis Length: 49.66645626499722
# Image: PM_NF_5309_13_20.jpeg, Object 1:
#   - Major Axis Length: 113.01431242867086
#   - Minor Axis Length: 81.71979002755795
# Image: PM_NF_5309_15_13.jpeg, Object 1:
#   - Major Axis Length: 64.15157486987638
#   - Minor Axis Length: 47.10952233077091
# Image: PM_NF_5310_02_43.jpeg, Object 1:
#   - Major Axis Length: 91.54837800788967
#   - Minor Axis Length: 65.15370980474427
# Image: PM_NF_5310_09_36.jpeg, Object 1:
#   - Major Axis Length: 75.34928759769029
#   - Minor Axis Length: 49.97324729817689
# Image: PM_NF_5311_26_25.jpeg, Object 1:
#   - Major Axis Length: 103.1492590519646
#   - Minor Axis Length: 75.47271564244467
# Image: PM_NF_5311_31_21.jpeg, Object 1:
#   - Major Axis Length: 98.2681675773491
#   - Minor Axis Length: 71.74416618381652
# Image: PM_NF_5311_43_45.jpeg, Object 1:
#   - Major Axis Length: 94.68280166874901
#   - Minor Axis Length: 61.524012016905374
# Image: PM_NF_5311_48_12.jpeg, Object 1:
#   - Major Axis Length: 69.11488973188096
#   - Minor Axis Length: 51.768868601511876
# Image: PM_NF_5311_61_5.jpeg, Object 1:
#   - Major Axis Length: 77.8452776201895
#   - Minor Axis Length: 59.63821110696183
# Image: PM_NF_5311_89_14.jpeg, Object 1:
#   - Major Axis Length: 70.44720037294739
#   - Minor Axis Length: 55.536599547889864
# Image: PM_NF_5311_93_40.jpeg, Object 1:
#   - Major Axis Length: 68.32426241254544
#   - Minor Axis Length: 44.20173970914962
# Image: PM_NF_5312_01_21.jpeg, Object 1:
#   - Major Axis Length: 116.46267104754497
#   - Minor Axis Length: 91.88982053989236
# Image: PM_NF_5338_03_21.jpeg, Object 1:
#   - Major Axis Length: 67.4208772923162
#   - Minor Axis Length: 47.780024522804815
# Image: PM_NF_5338_08_7.jpeg, Object 1:
#   - Major Axis Length: 70.66519196858856
#   - Minor Axis Length: 49.84131241958882
# Image: PM_NF_5338_13_11.jpeg, Object 1:
#   - Major Axis Length: 70.82008531820061
#   - Minor Axis Length: 45.04321204332076
# Image: PM_NF_5338_13_41.jpeg, Object 1:
#   - Major Axis Length: 61.1481050014723
#   - Minor Axis Length: 45.253507972007
# Image: PM_NF_5338_15_38.jpeg, Object 1:
#   - Major Axis Length: 68.7615446388889
#   - Minor Axis Length: 49.18214358714121
# Image: PM_NF_5338_16_35.jpeg, Object 1:
#   - Major Axis Length: 91.80462053790644
#   - Minor Axis Length: 69.14214138126873
# Image: PM_NF_5338_23_25.jpeg, Object 1:
#   - Major Axis Length: 80.76686668734598
#   - Minor Axis Length: 61.9437146960054
# Image: PM_NF_5338_31_21.jpeg, Object 1:
#   - Major Axis Length: 97.84221268046298
#   - Minor Axis Length: 73.40178454002657
# Image: PM_NF_5338_32_15.jpeg, Object 1:
#   - Major Axis Length: 77.37582899245966
#   - Minor Axis Length: 54.833022458699524
# Image: PM_NF_5338_36_19.jpeg, Object 1:
#   - Major Axis Length: 73.50743072504773
#   - Minor Axis Length: 49.60869710095244
# Image: PM_NF_5338_49_18.jpeg, Object 1:
#   - Major Axis Length: 96.71028418185706
#   - Minor Axis Length: 68.55550984197748
# Image: PM_NF_5338_50_42.jpeg, Object 1:
#   - Major Axis Length: 79.53623354359809
#   - Minor Axis Length: 53.40767381410483
# Image: PM_NF_5338_51_39.jpeg, Object 1:
#   - Major Axis Length: 95.51738465389883
#   - Minor Axis Length: 70.45184240896407
# Image: PM_NF_5338_55_39.jpeg, Object 1:
#   - Major Axis Length: 95.86885642873698
#   - Minor Axis Length: 76.96102465643988
# Image: PM_NF_5362_03_46.jpeg, Object 1:
#   - Major Axis Length: 105.37031533012225
#   - Minor Axis Length: 78.68051102892247
# Image: PM_NF_5362_34_2.jpeg, Object 1:
#   - Major Axis Length: 114.70541395618886
#   - Minor Axis Length: 80.15555110699941
# Image: PM_NF_5362_35_17.jpeg, Object 1:
#   - Major Axis Length: 91.73136417211849
#   - Minor Axis Length: 65.11974209010708
# Image: PM_NF_5368_01_25.jpeg, Object 1:
#   - Major Axis Length: 79.78545237938927
#   - Minor Axis Length: 58.807546239116014
# Image: PM_NF_5368_02_20.jpeg, Object 1:
#   - Major Axis Length: 76.2595122932957
#   - Minor Axis Length: 56.18908732376402
# Image: PM_NF_5377_22_31.jpeg, Object 1:
#   - Major Axis Length: 78.20637551795708
#   - Minor Axis Length: 58.51721653330881
# Image: PM_NF_5378_07_37.jpeg, Object 1:
#   - Major Axis Length: 69.51256616511826
#   - Minor Axis Length: 54.05555121131767
# Image: PM_NF_5379_04_28.jpeg, Object 1:
#   - Major Axis Length: 86.409443822857
#   - Minor Axis Length: 63.0139997504184
# Image: PM_NF_5379_07_46.jpeg, Object 1:
#   - Major Axis Length: 77.52928827515473
#   - Minor Axis Length: 59.74759867284199
# Image: PM_NF_5387_03_43.jpeg, Object 1:
#   - Major Axis Length: 115.48287076757559
#   - Minor Axis Length: 87.76126140699232
# Image: PM_NF_5395_16_40.jpeg, Object 1:
#   - Major Axis Length: 71.60038405286657
#   - Minor Axis Length: 50.3337488448194
# Image: PM_NF_5408_36_46.jpeg, Object 1:
#   - Major Axis Length: 81.38025784189078
#   - Minor Axis Length: 57.83606239144448
# Image: PM_NF_5408_45_36.jpeg, Object 1:
#   - Major Axis Length: 96.22432954275216
#   - Minor Axis Length: 74.44538327148545
# Image: PM_NF_5423_08_35.jpeg, Object 1:
#   - Major Axis Length: 105.42026234602781
#   - Minor Axis Length: 81.22178566179713
# Image: PM_NF_5429_21_45.jpeg, Object 1:
#   - Major Axis Length: 110.00153043868619
#   - Minor Axis Length: 76.70847642789943
# Image: PM_NF_5429_30_6.jpeg, Object 1:
#   - Major Axis Length: 108.2953613952315
#   - Minor Axis Length: 83.80537692630057
# Image: PM_NF_5429_44_42.jpeg, Object 1:
#   - Major Axis Length: 102.64473886372149
#   - Minor Axis Length: 82.95013794588066
# Image: PM_NF_5429_46_6.jpeg, Object 1:
#   - Major Axis Length: 76.73829849397828
#   - Minor Axis Length: 48.37869311358757
# Image: PM_NF_5429_63_7.jpeg, Object 1:
#   - Major Axis Length: 107.93175078639068
#   - Minor Axis Length: 73.75964117541955
# Image: PM_NF_5429_65_31.jpeg, Object 1:
#   - Major Axis Length: 98.10674588419329
#   - Minor Axis Length: 63.991004120668336
# Image: PM_NF_5429_65_43.jpeg, Object 1:
#   - Major Axis Length: 90.80622043218125
#   - Minor Axis Length: 65.6014595443986
# Image: PM_NF_5429_86_46.jpeg, Object 1:
#   - Major Axis Length: 96.10447386584852
#   - Minor Axis Length: 79.12031415068593
# Image: PM_NF_5429_132_26.jpeg, Object 1:
#   - Major Axis Length: 104.57030695416297
#   - Minor Axis Length: 78.13467329855537
# Image: PM_NF_5429_165_47.jpeg, Object 1:
#   - Major Axis Length: 109.08531641072018
#   - Minor Axis Length: 85.49832473964895
# Image: PM_NF_5429_181_33.jpeg, Object 1:
#   - Major Axis Length: 65.83621613294237
#   - Minor Axis Length: 47.9726632595037
# Image: PM_NF_5429_189_43.jpeg, Object 1:
#   - Major Axis Length: 95.1411994276273
#   - Minor Axis Length: 70.21395955456232
# Image: PM_NF_5430_11_29.jpeg, Object 1:
#   - Major Axis Length: 97.7267247813315
#   - Minor Axis Length: 69.72940012406615
# Image: PM_NF_5285_02_8.jpeg, Object 1:
#   - Major Axis Length: 77.76236957659388
#   - Minor Axis Length: 55.21372568336738
# Image: PM_NF_5285_02_25.jpeg, Object 1:
#   - Major Axis Length: 77.81553461701212
#   - Minor Axis Length: 52.277884632349036
# Image: PM_NF_5285_05_1.jpeg, Object 1:
#   - Major Axis Length: 91.03405964722269
#   - Minor Axis Length: 69.16060389247606
# Image: PM_NF_5291_01_12.jpeg, Object 1:
#   - Major Axis Length: 76.78063980164151
#   - Minor Axis Length: 58.36623430350083
# Image: PM_NF_5291_01_16.jpeg, Object 1:
#   - Major Axis Length: 94.14752023550196
#   - Minor Axis Length: 81.61105715503477
# Image: PM_NF_5291_02_26.jpeg, Object 1:
#   - Major Axis Length: 70.75296324395786
#   - Minor Axis Length: 53.75103471282607
# Image: PM_NF_5291_02_29.jpeg, Object 1:
#   - Major Axis Length: 100.60335326744759
#   - Minor Axis Length: 78.27351066610335
# Image: PM_NF_5291_02_44.jpeg, Object 1:
#   - Major Axis Length: 86.71153301536347
#   - Minor Axis Length: 64.32090258044173
# Image: PM_NF_5291_03_19.jpeg, Object 1:
#   - Major Axis Length: 102.22259640783925
#   - Minor Axis Length: 89.09612735006134
# Image: PM_NF_5291_10_25.jpeg, Object 1:
#   - Major Axis Length: 62.75210313343268
#   - Minor Axis Length: 40.45859969167526
# Image: PM_NF_5291_13_1.jpeg, Object 1:
#   - Major Axis Length: 73.75610407245696
#   - Minor Axis Length: 55.811740292165446
# Image: PM_NF_5291_18_45.jpeg, Object 1:
#   - Major Axis Length: 77.13578427493971
#   - Minor Axis Length: 51.428194851299445
# Image: PM_NF_5291_19_6.jpeg, Object 1:
#   - Major Axis Length: 92.68828954371841
#   - Minor Axis Length: 68.0579473832155
# Image: PM_NF_5301_06_13.jpeg, Object 1:
#   - Major Axis Length: 119.17885898327869
#   - Minor Axis Length: 88.2786550481629
# Image: PM_NF_5306_03_44.jpeg, Object 1:
#   - Major Axis Length: 62.879704321733286
#   - Minor Axis Length: 53.78118068405753
# Image: PM_NF_5306_80_4.jpeg, Object 1:
#   - Major Axis Length: 63.77681736110348
#   - Minor Axis Length: 46.86623666259571
# Image: PM_NF_5306_108_41.jpeg, Object 1:
#   - Major Axis Length: 93.16383299531664
#   - Minor Axis Length: 71.68396513258203
# Image: PM_NF_5309_19_20.jpeg, Object 1:
#   - Major Axis Length: 72.43313913828494
#   - Minor Axis Length: 50.56802161042667
# Image: PM_NF_5309_19_29.jpeg, Object 1:
#   - Major Axis Length: 92.14037652900217
#   - Minor Axis Length: 62.35599448288541
# Image: PM_NF_5311_105_16.jpeg, Object 1:
#   - Major Axis Length: 97.25835485039893
#   - Minor Axis Length: 67.95671151108873
# Image: PM_NF_5338_14_14.jpeg, Object 1:
#   - Major Axis Length: 86.23505058327859
#   - Minor Axis Length: 57.73033564585634
# Image: PM_NF_5338_17_5.jpeg, Object 1:
#   - Major Axis Length: 80.53601294356456
#   - Minor Axis Length: 53.197332282309574
# Image: PM_NF_5338_33_29.jpeg, Object 1:
#   - Major Axis Length: 79.65220460468076
#   - Minor Axis Length: 58.301691235257074
# Image: PM_NF_5338_34_14.jpeg, Object 1:
#   - Major Axis Length: 74.5396227812126
#   - Minor Axis Length: 54.67545636919274
# Image: PM_NF_5338_57_29.jpeg, Object 1:
#   - Major Axis Length: 83.68069520891508
#   - Minor Axis Length: 66.31442578097709
# Image: PM_NF_5341_11_30.jpeg, Object 1:
#   - Major Axis Length: 118.22078733568458
#   - Minor Axis Length: 87.57799812771837
# Image: PM_NF_5341_22_27.jpeg, Object 1:
#   - Major Axis Length: 95.65742785728547
#   - Minor Axis Length: 69.19283516059805
# Image: PM_NF_5362_21_36.jpeg, Object 1:
#   - Major Axis Length: 106.124182053645
#   - Minor Axis Length: 80.35731784927063
# Image: PM_NF_5384_34_16.jpeg, Object 1:
#   - Major Axis Length: 75.9143198589377
#   - Minor Axis Length: 57.68103979581576
# Image: PM_NF_5423_03_4.jpeg, Object 1:
#   - Major Axis Length: 95.17293579840212
#   - Minor Axis Length: 68.48123646984867
# Image: PM_NF_5423_03_19.jpeg, Object 1:
#   - Major Axis Length: 95.95584937883731
#   - Minor Axis Length: 73.12803115209111
# Image: PM_NF_5429_102_44.jpeg, Object 1:
#   - Major Axis Length: 87.04619592816006
#   - Minor Axis Length: 52.94013718896134
# Image: PM_NF_5429_163_36.jpeg, Object 1:
#   - Major Axis Length: 97.70181961054206
#   - Minor Axis Length: 71.65185665019378
# Image: PM_NF_5429_173_17.jpeg, Object 1:
#   - Major Axis Length: 99.77789924570835
#   - Minor Axis Length: 71.08420540065809
# Image: PM_NF_5429_186_20.jpeg, Object 1:
#   - Major Axis Length: 75.99356359888108
#   - Minor Axis Length: 59.1354023616371
# Image: PM_NF_4999_10_4.jpeg, Object 1:
#   - Major Axis Length: 80.55168005097092
#   - Minor Axis Length: 66.71985551347898
# Image: PM_NF_4999_22_25.jpeg, Object 1:
#   - Major Axis Length: 92.0085785298916
#   - Minor Axis Length: 63.62852007134195
# Image: PM_NF_5027_01_35.jpeg, Object 1:
#   - Major Axis Length: 71.55311406170942
#   - Minor Axis Length: 52.92390259894375
# Image: PM_NF_5065_15_37.jpeg, Object 1:
#   - Major Axis Length: 97.09905738901368
#   - Minor Axis Length: 72.03110756288403
# Image: PM_NF_5217_01_39.jpeg, Object 1:
#   - Major Axis Length: 109.18290100783891
#   - Minor Axis Length: 92.93408401772379
# Image: PM_NF_5225_05_37.jpeg, Object 1:
#   - Major Axis Length: 107.47697170347696
#   - Minor Axis Length: 77.61079042434217
# Image: PM_NF_5225_20_34.jpeg, Object 1:
#   - Major Axis Length: 74.31363562641776
#   - Minor Axis Length: 47.49481370587807
# Image: PM_NF_5285_08_48.jpeg, Object 1:
#   - Major Axis Length: 74.60484026514578
#   - Minor Axis Length: 56.96748324587788
# Image: PM_NF_5285_10_46.jpeg, Object 1:
#   - Major Axis Length: 77.02160189535026
#   - Minor Axis Length: 58.289540762389684
# Image: PM_NF_5290_18_24.jpeg, Object 1:
#   - Major Axis Length: 91.26786718010162
#   - Minor Axis Length: 66.97900581084212
# Image: PM_NF_5290_21_27.jpeg, Object 1:
#   - Major Axis Length: 85.38679228801219
#   - Minor Axis Length: 54.624720813274074
# Image: PM_NF_5290_25_33.jpeg, Object 1:
#   - Major Axis Length: 67.19752078960823
#   - Minor Axis Length: 46.612450940036986
# Image: PM_NF_5291_06_36.jpeg, Object 1:
#   - Major Axis Length: 64.75767877925738
#   - Minor Axis Length: 50.40542189178405
# Image: PM_NF_5291_08_6.jpeg, Object 1:
#   - Major Axis Length: 62.698973066547936
#   - Minor Axis Length: 42.055936198811345
# Image: PM_NF_5291_18_2.jpeg, Object 1:
#   - Major Axis Length: 93.5271372136473
#   - Minor Axis Length: 64.84883402032
# Image: PM_NF_5291_23_21.jpeg, Object 1:
#   - Major Axis Length: 112.48862906905724
#   - Minor Axis Length: 81.75919603033893
# Image: PM_NF_5291_25_35.jpeg, Object 1:
#   - Major Axis Length: 92.76013118928597
#   - Minor Axis Length: 64.68392966564468
# Image: PM_NF_5301_06_12.jpeg, Object 1:
#   - Major Axis Length: 86.86411747881743
#   - Minor Axis Length: 57.88786445475778
# Image: PM_NF_5306_04_27.jpeg, Object 1:
#   - Major Axis Length: 95.32295649713475
#   - Minor Axis Length: 73.09631521404089
# Image: PM_NF_5306_60_16.jpeg, Object 1:
#   - Major Axis Length: 86.24019755512234
#   - Minor Axis Length: 70.3920659082257
# Image: PM_NF_5306_68_9.jpeg, Object 1:
#   - Major Axis Length: 72.46887659551247
#   - Minor Axis Length: 49.58516159763485
# Image: PM_NF_5306_120_19.jpeg, Object 1:
#   - Major Axis Length: 64.02557715924867
#   - Minor Axis Length: 44.35791110632453
# Image: PM_NF_5311_05_3.jpeg, Object 1:
#   - Major Axis Length: 84.03864353435893
#   - Minor Axis Length: 65.7103173218273
# Image: PM_NF_5311_69_36.jpeg, Object 1:
#   - Major Axis Length: 87.76224073491095
#   - Minor Axis Length: 59.02888269092158
# Image: PM_NF_5338_07_40.jpeg, Object 1:
#   - Major Axis Length: 84.65093574463539
#   - Minor Axis Length: 57.298724878950935
# Image: PM_NF_5338_27_2.jpeg, Object 1:
#   - Major Axis Length: 102.03546220451707
#   - Minor Axis Length: 79.2573876897396
# Image: PM_NF_5338_30_24.jpeg, Object 1:
#   - Major Axis Length: 69.93618735181369
#   - Minor Axis Length: 53.258077431424944
# Image: PM_NF_5338_42_40.jpeg, Object 1:
#   - Major Axis Length: 70.64267075147546
#   - Minor Axis Length: 53.907291753487904
# Image: PM_NF_5338_56_27.jpeg, Object 1:
#   - Major Axis Length: 82.97927181192715
#   - Minor Axis Length: 49.87839040898423
# Image: PM_NF_5362_22_39.jpeg, Object 1:
#   - Major Axis Length: 65.848562681465
#   - Minor Axis Length: 45.620068760649296
# Image: PM_NF_5384_01_48.jpeg, Object 1:
#   - Major Axis Length: 87.81462680023272
#   - Minor Axis Length: 61.36490915178368
# Image: PM_NF_5384_51_24.jpeg, Object 1:
#   - Major Axis Length: 74.91891206181282
#   - Minor Axis Length: 61.23565755366256
# Image: PM_NF_5408_29_31.jpeg, Object 1:
#   - Major Axis Length: 103.98146426241061
#   - Minor Axis Length: 71.4150440551354
# Image: PM_NF_5429_56_8.jpeg, Object 1:
#   - Major Axis Length: 97.3810622747411
#   - Minor Axis Length: 62.616081109336704
# Image: PM_NF_5429_81_6.jpeg, Object 1:
#   - Major Axis Length: 99.4028555535068
#   - Minor Axis Length: 73.13563320255373
# Morphometrics successfully saved to CSV file.
